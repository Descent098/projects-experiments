# %%
import spark
# %reload_ext spark

# %%
# %%ignite
#
# # Step 1; Setting up variables
# x = 0
# y = 0
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global x, y # Step 2; Grab x and y from global scope
#     fill_rect(x,y,50,50) # Step 3; use x and y
#
#     # Step 4 Update x and y
#     x += 75
#     y += 75

# %%
# %%ignite
#
# g = 0 # Step 1; setup the g variable
#
# #step 1
# x = 0
# y = 0
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global g, x, y # Step 2; Get the g variable from global scope
#     background("white")
#     fill_style(0, g, 0) # Step 3; use the g variable
#     fill_circle(x, y, 100)
#     g += 1 # Step 4; Update g (in this case add to it)
#     y += 5
#     x += 5
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# x = 0
#
# def setup():
#     size(500,250)
#
# def draw():
#     global x
#     diameter, y = 50, 25
#     background(0)
#     x += 5
#     fill_style("White")
#     fill_circle(x, y, diameter)
#
#     if x == (500 - (diameter/2) ):
#         x = 0 # reset to top left
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %% [markdown]
# # Ball moving from top left to right

# %%
# %%ignite
#
# x = 25
#
# def setup():
#     size(500,250)
#
# def draw():
#     global x
#     background("White")
#     fill_circle(x, 25, 50)
#     x += 10
#     if x >= 500:
#         x = 25
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(300,300)
#
# def draw():
#     background("White")
#
#     fill_circle(mouse_x, mouse_y, 50)
#
#     if mouse_x > 125 and mouse_y > 125: # Bottom right
#         fill_style("Blue")
#     elif mouse_x < 125 and mouse_y >125: # Bottom left
#         fill_style("Yellow")
#     elif mouse_x < 125 and mouse_y < 125: # Top left
#         fill_style("Red")
#     else: # Top right
#         fill_style("Green")
#
#     left = mouse_x < 125
#     right = True
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %% [markdown]
# # Better version using variables

# %%
# %%ignite
#
# def setup():
#     size(300,300)
#
# def draw():
#     background("White")
#
#     left = mouse_x < 150 # Will be True if in the left
#     top = mouse_y < 150  # Will be True if in the top
#     right = not left
#
#     fill_circle(mouse_x, mouse_y, 50)
#     if top and left: # top left
#         fill_style("Red")
#     elif top and not left: # Top right
#         fill_style("Green")
#     elif not top and not left: # Bottom right
#         fill_style("Blue")
#     else:# Bottom left
#         fill_style("Yellow")
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
# shopping_list = ["Eggs", "Ham", "turkey"]
# shopping_list.append("Bacon")
# print(shopping_list)
#
#
# x_positions = [50, 100, 150, 200]
#
# def setup():
#     size(300, 300)
#
# def draw():
#     global x_positions
#     fill_circle(x_positions[0], 20, 50)
#     x_positions[0] += 3
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# ['Eggs', 'Ham', 'turkey', 'Bacon']

# %%
# %%ignite
# def setup():
#     size(500,500)
#     fill_ellipse(250, 250, 20, 60)
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup(): # Only drawn once, so just using setup()
#     print(randint(10))
#     print(random())
# Out:
# Done drawing.
# Canvas(height=100, width=100)
# 4
# 0.6258217529177709

# %%
# %%ignite
# def setup():
#     size(500,500)
# def draw():
#
#     circle("2.3",250,200)
# Out:
# Error in draw() function: Invalid types for circle with 3 arguments, expected
# 	circle(Real, Real, Real)
# received circle(2.3: str, 250: int, 200: int)
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
# def setup():
#     size(200,200)
# def draw():
#     background(255)
#     text_size(32)
#     text(key,100,100)
# # def key_pressed():
# #     print("A key was pressed bucko")
#
# # def key_repeated():
# #     print("A key was repeated bucko")
#
# # def key_released():
# #     print("A key was released bucko")
# Out:
# Stopped due to inactivity
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#
# def draw():
#
#     fill_style("red")
#     triangle(25, 150, 150, 150, 80, 50)
#
#     fill_triangle(200, 150, 300, 150, 250, 50)
#
#     stroke_triangle(350, 150, 450, 150, 400, 50)
# Out:
# Stopped due to inactivity
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(200, 200)
#
# def draw():
#     stroke_rect(100, 100, 75, 50)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(200, 200)
#
# def draw():
#     if keys_held("b"):
#         print("b key held")
# Out:
# Stopped due to inactivity
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held
# b key held

# %%
# %%ignite
#
# def setup():
#     size(200, 200)
#
# def draw():
#     ... # Does nothing
#
# def key_repeated():
#     print(key)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# s
# s
# s
# s
# s
# s
# s
# s
# s
# s
# s
# s
# s

# %%
# %%ignite
#
# def setup():
#     size(100, 100)
#
# def draw():
#     background(0)
#     text(keys_held("a", "b"), 50, 50)

# %% [markdown]
# ## Snake Game

# %%
# %%ignite
#
# # Player state
# score = 0
# speed_y = 0
# speed_x = 10
# positions = [[150, 100]]
#
# # Game state
# highscore = 0
# game_over = False
# WIDTH = 300
# HEIGHT = 300
#
# def get_treat_pos() -> tuple: # Needs to be defined here so treat_pos can be initialized
#     """Generates the new treat position
#
#     Returns
#     -------
#     list:
#         The new coordinates in (x, y) order
#     """
#     global WIDTH, HEIGHT
#     # Generate x pos
#     value_x = randint(WIDTH - 30) + 10
#     while not (value_x % 10 == 0):
#         value_x = randint(WIDTH - 30) + 10
#
#     # Generate y pos
#     value_y = randint(HEIGHT - 60) + 10
#     while not (value_y % 10 == 0):
#         value_y = randint(HEIGHT - 60) + 10
#
#     return [value_x, value_y]
#
# # Initialize treat position
# treat_pos = get_treat_pos()
#
# def setup():
#     size(WIDTH, HEIGHT)
#
# def draw():
#     if not game_over:
#         gameloop()
#     else:
#         restart()
#
# def gameloop():
#     global highscore, score, game_over, positions, speed_x, speed_y, treat_pos
#     background(0)
#
#     # Check and draw player treat
#     fill_style("Red")
#     square(treat_pos[0], treat_pos[1], 10)
#
#     # Set drawing colors
#     fill_style("White")
#     seen = [] # Holds seen chunk positions
#
#     # treat collision
#     if positions[0] == treat_pos:
#         score += 1
#
#         # Create new treat
#         treat_pos = get_treat_pos()
#
#         # Append new segment to snake
#         positions.append([positions[-1][0], positions[-1][1]])
#
#     # Set new highscore if reached
#     if highscore < score:
#         highscore = score
#
#     # Print helpful text at the top
#     text_size(20)
#     text(f"Score: {score}", 50, 10)
#     text(f"Highscore: {highscore}", 150, 10)
#
#     # Move all snek chunks besides head, starting from the back
#     for index in range(len(positions)-1, 0, -1):
#         positions[index][0] = positions[index-1][0]
#         positions[index][1] = positions[index-1][1]
#
#     # Check for all collisions besides treat collision
#     for index, position in enumerate(positions):
#         # Check collision with snek head and other segments
#         if position in seen:
#             game_over = True
#             break
#         else:
#             seen.append(position)
#
#         if index == 0: # update First square
#             # Check keypress in key_pressed
#             position[0] += speed_x
#             position[1] += speed_y
#
#         # Segment colisions with outer bounds
#         if position[0] > WIDTH - 10: # Hit right boundary
#             position[0] = 0
#         if position[0] < 0: # Hit left boundary
#             position[0] = 290
#
#         # Check y colisions
#         if position[1] < 20: # Hit top boundary
#             position[1] = 290
#
#         if position[1] > HEIGHT - 10: # Hit bottom boundary
#             position[1] = 20
#
#         # Update current square to new position
#         square(position[0], position[1], 10)
#
# def key_pressed():
#     """Controls all snek movement"""
#     global speed_x, speed_y
#     if key == "d": # Right
#         speed_x = 10
#         speed_y = 0
#     if key == "a": # Left
#         speed_x = -10
#         speed_y = 0
#     if key == "s": # Down
#         speed_y = 10
#         speed_x = 0
#     if key == "w": # Up
#         speed_y = -10
#         speed_x = 0
#
# def restart():
#     """Resets game state after colliding with yourself"""
#     global score, game_over, positions
#     score = 0
#     game_over = False
#     positions = [[150,100]]

# %%
# %%ignite
#
# selectors = ["yeet", 1, "asdfj", 7]
#
# def setup():
#     size(200,200)
#
# def draw():
#     background(255)
#     text_size(32)
#     today = datetime().today().date()
#
#     text(today,20,100)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# y_list = [50, 130, 275, 400]
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global y_list
#     background(255, 255, 100)
#
#     fill_style("blue")
#     rect(0, y_list[0], mouse_x, 30)
#     rect(0, y_list[1], mouse_x, 30)
#     rect(0, y_list[2], mouse_x, 30)
#     rect(0, y_list[3], mouse_x, 30)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#
# def draw():
#
#     y_positions = [50, 100, 150, 200, 250]
#     background(255, 255, 100)
#     fill_style("blue")
#
#     y = y_positions[0]
#     rect(0, y, mouse_x  , 30 )
#     y = y_positions[1]
#     rect(0, y, mouse_x  , 30 )
#     y = y_positions[2]
#     rect(0, y, mouse_x  , 30 )
#     y = y_positions[3]
#     rect(0, y, mouse_x  , 30 )
#
#     for y in y_positions:
#         rect(0, y, mouse_x  , 30 )
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# xPos = [30,90,150,210,270]
# yPos = 0
# y_speed = 0
#
# def setup():
#     size(300, 300)
#
# def draw():
#     global xPos, yPos, y_speed
#     background(0, 0, 0)
#     yPos += y_speed
#     y_speed += 0.5
#
#     for x in xPos:
#         if x > 150:
#             fill_style(184, 232, 238)
#         elif x == 150:
#             fill_style(225, 162, 61)
#         else:
#             fill_style(184, 101, 143)
#         circle(x, yPos, 30)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# shopping_list = []
#
# def setup():
#     size(200,200)
#     text_size(23)
#
#
# def draw():
#     y = 0
#     for item in shopping_list:
#         text(item, 0, y)
#         y += 50
#     new_item = str(input("What would you like to add?:"))
#     shopping_list.append(new_item)
# Out:
# Error in draw() function: EOF when reading a line
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# What would you like to add?: k

# %%
# %%ignite
#
# y = 0
# x_positions = [50, 100, 150, 200, 250, 300]
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global y, x_positions
#
#     background("White")
#
#     for x in x_positions:
#         circle(x, y, 50)
#
#     y+= 5
#
#     if y >= 500:
#         y = 5
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# y = 0
# x_positions = [50, 100, 150, 200, 250, 300]
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global y, x_positions
#     background("White")
#     circle(x_positions[0], y, 50)
#     circle(x_positions[1], y, 50)
#     circle(x_positions[2], y, 50)
#     circle(x_positions[3], y, 50)
#     circle(x_positions[4], y, 50)
#     circle(x_positions[5], y, 50)
#
#     y+= 5
#     if y >= 500:
#         y = 5
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(500,500)
#
# def draw():
#     triangle(110, 75, 75, 150, 150, 150)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# hello

# %%
# %%ignite
#
# def setup():
#     size(500,500)
#
# def draw():
#     print(mouse_is_pressed)
#
# def mouse_down():
#     print("Mouse down")
#
# def mouse_up():
#     print("Mouse Up")
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# Mouse down
# True
# True
# Mouse Up
# False
# False
# False
# False
# Mouse Up
# False
# False
# Mouse down
# True
# Mouse Up
# False
# False
# False
# False
# Mouse Up
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
# %%ignite
# def setup():
#     background(255)
#     size(500,500)
#
# def draw():
#     if mouse_is_pressed:
#         square(mouse_x, mouse_y, 45)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(200, 200)
#
# def draw():
#     ... # Does nothing
#
# def mouse_up():
#     print("Mouse Button Released")
# Out:
# Stopped due to inactivity
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# Mouse Button Released
