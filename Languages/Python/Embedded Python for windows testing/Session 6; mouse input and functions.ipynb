# %% [markdown]
# ## Topics
#
# - Checking for mouse clicks
#   - mouse_is_pressed
#   - mouse_down()
#   - mouse_up()
# - Defining our own Functions
# ---

# %%
import spark
# %reload_ext spark

# %% [markdown]
# ## Exercise 1; Random circle function
#
# *Create a function called random_circle that gets called when the mouse is pressed*
#
# ### Requirements
# - [ ] The function should draw a circle at the mouse position with a random diameter (range 25-75) and random color.
#
# **Hint: Remember that randint(50) gives you a random number from 0 to 50**
#
# ### Starter code
#
# ```python
# %%ignite
#
# def setup():
#     size(500, 500)
#     background(240,240,240)
#
# def draw():
#     if mouse_is_pressed:
#         randomCircle()
#
# def randomCircle():
#     ... # Write code to generate a random circle here
# ```

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#     background(240,240,240)
#
# def draw():
#     if mouse_is_pressed:
#         randomCircle()
#
# def randomCircle():
#     r = randint(256)
#     g = randint(256)
#     b = randint(256)
#
#     d = randint(50) + 25
#     fill_style(r,g,b)
#
#     circle(mouse_x, mouse_y, d)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#     background(240,240,240)
#
# def draw():
#     if mouse_is_pressed:
#         random_circle_list() # You can use either random_circle_list() or random_circle_ints() here
#
# def random_circle_list():
#     colors = ["green", "brown", "blue", "orange", "red"]
#     fill_style(colors[randint(4)])
#     fill_circle(mouse_x, mouse_y, randint(250))
#
# def random_circle_ints():
#     r = randint(255)
#     g = randint(255)
#     b = randint(255)
#
#     fill_style(r, g, b)
#     fill_circle(mouse_x, mouse_y, randint(250))

# %% [markdown]
# ## Exercise #2 - Tying it all Together
#
# ### Requirements
# Create a function named average() that returns the average of two inputs when the mouse is pressed:
#     - Call average() and pass in mouse_x and mouse_y as the parameters
#     - Draw a stroke_circle() at position of the mouse with the return value of average() as the diameter
#
# ### Starter code
# ```python
# %%ignite
#
# def setup():
#     size(500,500)
#     background(152,225,239)
#
#
# def draw():
#     if mouse_is_pressed:
#         d = average() # Need 2 arguments here
#         stroke_circle(mouse_x,mouse_y,d)
#
# def average():
#     ... # Fill out function parameters and return value
# ```

# %%
# %%ignite
#
# def setup():
#     size(500,500)
#     background(152,225,239)
#
#
# def draw():
#     if mouse_is_pressed:
#         d = average(mouse_x,mouse_y)
#         stroke_circle(mouse_x,mouse_y,d)
#
# def average(a,b):
#     return a+b/2
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(500,500)
#     background(152,225,239)
#
#
# def draw():
#     if mouse_is_pressed:
#         d = average(mouse_x, mouse_y)
#         stroke_circle(mouse_x, mouse_y, d)
#
# def average(x, y):
#     return (x + y)/2
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#
#
# def draw():
#     if mouse_is_pressed:
#         draw_snowman(mouse_x, mouse_y)
#
# def draw_snowman():
#     ...
# Out:
# Error in draw() function: 'int' object is not callable
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
