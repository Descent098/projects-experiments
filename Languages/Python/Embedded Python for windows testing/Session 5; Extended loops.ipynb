# %% [markdown]
# # Topics
#
# - For...in range loops
# - While loops
# - Getting inputs
# - Examples - Lots of Practice!
#
# ---

# %% [markdown]
# # Exercise 1; Make it Rain
# Make 6 raindrops fall down with different speeds. Use 3 lists
# - x_list
# - y_list
# - speed_list
#
# Bonus: Make the raindrops jump back to the beginning and fall again when they hit the bottom
#
# ### Template to get you started
#
# ```python
# %%ignite
#
# drops_x = [100, 160, 240, 280, 330, 370]
# drops_y = [100, 100, 100, 100, 100, 100]
# speeds_y = [4, 3, 10, 7, 5, 12]
# drops_width = 10
# drops_height = 20
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global drops_x, drops_y, speeds_y, drops_width, drops_height
#     background("darkblue")
#
#     fill_style(200, 220, 255)
#     for i in range(): # Code needs to go here
#         ...
#
#     # Draws clouds
#     fill_style(200)
#     fill_circle(140, 70, 80)
#     fill_circle(220, 60, 120)
#     fill_circle(280, 60, 100)
#     fill_circle(340, 70, 70)
# ```

# %%
import spark
# %reload_ext spark

# %%
# %%ignite
#
# drops_x = [100, 160, 240, 280, 330, 370]
# drops_y = [100, 100, 100, 100, 100, 100]
# speeds_y = [4, 3, 10, 7, 5, 12]
# droplet_width = 10
# droplet_height = 20
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global drops_x, drops_y, speeds_y
#     background("darkblue")
#
#     fill_style(200, 220, 255)
#     for i in range(len(drops_x)):
#         """Make a loop that:
#         - goes through the droplet x, and droplet y value
#         - Updated the droplet y with the speed values
#         - Resets when the droplet hits the bottom of the canvas
#         """
#         fill_rect(drops_x[i], drops_y[i], droplet_width, droplet_height)
#
#         drops_y[i] += speeds_y[i]
#
#         if drops_y[i] > height:
#             drops_y[i] = 100
#
#     # Draws clouds
#     fill_style(200)
#     fill_circle(140, 70, 80)
#     fill_circle(220, 60, 120)
#     fill_circle(280, 60, 100)
#     fill_circle(340, 70, 70)
# Out:
# Running...
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %% [markdown]
# ---
# # Our turn

# %%
# %%ignite
#
# drops_x = [100, 160, 240, 280, 330, 370]
# drops_y = [100, 100, 100, 100, 100, 100]
# speeds_y = [4, 3, 10, 7, 5, 12]
# drops_width = 10
# drops_height = 20
#
# def setup():
#     size(500, 500)
#
# def draw():
#     global drops_x, drops_y, speeds_y, drops_width, drops_height
#     background("darkblue")
#
#     fill_style(200, 220, 255)
#     list_length = len(drops_x)
#     for number in range(list_length): # Code needs to go here
#         rect(drops_x[number], drops_y[number], drops_width, drops_height)
#         drops_y[number] += speeds_y[number]
#
#
#
#     # Draws clouds
#     fill_style(200)
#     fill_circle(140, 70, 80)
#     fill_circle(220, 60, 120)
#     fill_circle(280, 60, 100)
#     fill_circle(340, 70, 70)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %% [markdown]
# # Exercise 2; Starting from the top
# Use a while loop to build a growing pyramid of bars
#
#
#
# ### Template to get you started
#
# ```python
# %%ignite
#
# def setup():
#     size(500, 500)
#
# def draw():
#     background(255, 255, 150)
#
#     fill_style("orange")
#     y = 10
#     while y < mouse_y:
#         rect(10, y, y, 30)
#         ... # Write rest of code here
# ```

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#
# def draw():
#     background(255, 255, 150)
#
#     fill_style("orange")
#     y = 10
#     while y < mouse_y:
#         rect(10, y, y, 30)
#         y += 50
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %% [markdown]
# ---
# ## Our turn

# %%
# %%ignite
#
# def setup():
#     size(500, 500)
#
# def draw():
#     background(255, 255, 150)
#
#     fill_style("orange")
#     y = 10
#     while y < mouse_y:
#         rect(10, y, y, 30)
#         y += 50
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# x = 150
# y = 150
#
# def setup():
#     size(300,300)
#
# def draw():
#     global x,y
#     background (80,184,208)
#
#     if keys_held("w"):
#         y -= 5
#     elif keys_held("s"):
#         y += 5
#     elif keys_held("a"):
#         x -= 5
#     elif keys_held("d"):
#         x += 5
#
#     circle(x,y,50)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
# %%ignite
#
# x = 150
# y = 150
#
# def setup():
#     size(300,300)
#
# def draw():
#     global x,y
#     background (80,184,208)
#
#     if keys_held("w"):
#         y -= 5
#     if keys_held("a"):
#         x -= 5
#     if keys_held("s"):
#         y += 5
#     if keys_held("d"):
#         x += 5
#
#     circle(x,y,50)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
