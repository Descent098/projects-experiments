# %%
import spark
# %reload_ext spark

# %%
# %%ignite
# # Collide and bounce - Red and blue rects should collide in middle and bounce in opposite directions
# x1 = -300
# y1 = 200
# w1 = 50
# h1 = 100
# speed1 = 3
#
# x2 = 775
# y2 = 225
# w2 = 25
# h2 = 50
# speed2 = -4
#
# def setup():
#     size(500, 500)
# def draw():
#     global x1, y1, w1, h1, speed1
#     global x2, y2, w2, h2, speed2
#     background("purple")
#
#     if collided(bounding_box(x1, y1, w1, h1), bounding_box(x2, y2, w2, h2)):
#         speed1 *= -1
#         speed2 *= -1
#
#     x1 += speed1
#     x2 += speed2
#
#     fill_style("red")
#     rect(x1, y1, w1, h1)
#     fill_style("blue")
#     rect(x2, y2, w2, h2)
# Out:
# Stopped
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}

# %%
walls_x = [10, 30] # The x value of each wall
walls_y = [10, 30] # The y value of each wall
walls_width = [20, 40] # the width of each wall
wall_height = [20, 40] # The height of each wall


for index in range(len(walls_width)): #count from 0 to length of walls_width list
    x = walls_x[index]
    y = walls_y[index]
    width = walls_width[index]
    height = walls_height[index]
    
    rect(x, y, width, height)
    b1 = bounding_box(x, y, width, height)
    b2 = bounding_box(...) # This is where your player values would go
    
    if collided(b1, b2):
        ... # do stuff if there's a collision

# %%
# %%ignite
#
# # Player 1 coordinates
# x = 10
# y = 10
#
# # Player 2 coordinates
# x_2 = 800
# y_2 = 350
#
#
# game_over = False
#
# rect(0,300,300,5)
# walls_x = [0, 200, 500, 300, 390, 590, 750, 600, 600, 290, 80,]
# walls_y = [300, 0, 0, 100, 200, 200, 50, 90, 280, 180, 50,]
# walls_width = [300, 5, 5, 200, 5, 600, 5, 40, 40, 40, 30,]
# walls_height = [5, 200, 250, 5, 200, 5, 300, 40, 40, 40, 190]
#
#
#
# def setup():
#     #the map for the tank game
#     size(900,400)
#
# def draw():
#     global x,y, x_2, y_2, game_over
#     if game_over:
#         background("white")
#         text_size(40)
#         text("Game over", 450, 200)
#
#     else:
#
#         background("white")
#         stroke_rect(0,0,900,400)
#         stroke_width(10)
#
#         # Player 1
#
#         # Movement
#         if keys_held("d"):
#             x+=9
#         if keys_held("a"):
#             x-=9
#         if keys_held("w"):
#             y-=9
#         if keys_held("s"):
#             y+=9
#
#         # Shooting
#         if keys_held("d") and keys_held("1"):
#             ... # shoot Right
#         if keys_held("a") and keys_held("1"):
#             ... # Shoot left
#         if keys_held("w") and keys_held("1"):
#             ... # Shoot up
#         if keys_held("s") and keys_held("1"):
#             ...  # Shoot down
#
#         rect(x,y,10,10)
#         player_1_bounding_box = bounding_box(x,y,10,10)
#
#         # Check colisions and end game if wall is hit
#         for index in range(len(walls_x)): # Go through each wall and draw it + check for player collisions
#             rect(walls_x[index],walls_y[index],walls_width[index],walls_height[index]) # Draw the current wall
#             if collided(bounding_box(walls_x[index],walls_y[index],walls_width[index],walls_height[index]), player_1_bounding_box): # Check player colision against current wall
#                 game_over = True
#
#         # Player 2
#
#         # Movement
#         if keys_held("l"):
#             x_2+=9
#         if keys_held("j"):
#             x_2-=9
#         if keys_held("i"):
#             y_2-=9
#         if keys_held("k"):
#             y_2+=9
#
#         # Shooting
#         if keys_held("l") and keys_held("1"):
#             ... # shoot Right
#         if keys_held("j") and keys_held("1"):
#             ... # Shoot left
#         if keys_held("i") and keys_held("1"):
#             ... # Shoot up
#         if keys_held("k") and keys_held("1"):
#             ...  # Shoot down
#
#         # Draw player & get boundary box
#         rect(x_2,y_2,10,10)
#         player_2_bounding_box = bounding_box(x_2,y_2,10,10)
#
#         # Check colisions and end game if wall is hit
#         for index in range(len(walls_x)): # Go through each wall and draw it + check for player collisions
#             rect(walls_x[index],walls_y[index],walls_width[index],walls_height[index]) # Draw the current wall
#             if collided(bounding_box(walls_x[index],walls_y[index],walls_width[index],walls_height[index]), player_2_bounding_box): # Check player colision against current wall
#                 game_over = True
# Out:
# Running...
# Button(description='Stop', style=ButtonStyle())
# Canvas(height=100, width=100)
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
